# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ls
# Out:
# Applications/                   VirtualBox VMs/
# Desktop/                        anaconda3/
# Documents/                      anjul.jpg*
# Downloads/                      daily_weather.csv
# IdeaProjects/                   database.sqlite
# Image Processing.ipynb*         example.csv*
# Library/                        matplotlib.ipynb
# ML - Classification.ipynb       minute_weather.csv
# ML - Clustring.ipynb            ml-20m/
# Movies/                         nltk_data/
# Music/                          numpy.ipynb*
# NLP.ipynb                       pandas.ipynb*
# Pictures/                       seaborn-data/
# Public/                         seaborn.ipynb
# Spark/                          secret_twitter_credentials.pkl
# Twitter analysis.ipynb          world-development-indicators/

# %%
# !cwd
# Out:
# /bin/sh: cwd: command not found

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], hist=False, color='green')

# %%
sns.distplot(tips['total_bill'], kde=False, bins=30, color='green')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(data=tips,hue='sex')

# %%
sns.rugplot(tips['total_bill'])

# %%
#matrix plotting

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot=True)

# %%
ft=flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(ft, linecolor='white', linewidths = 1, cmap='coolwarm')

# %%
sns.clustermap(ft,cmap='coolwarm',standard_scale=1)

# %%
#grid

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)
